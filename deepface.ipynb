# %%
from deepface import DeepFace
# Out:
# Directory  /home/heemin /.deepface created
# Directory  /home/heemin /.deepface/weights created

# %%
import cv2
import numpy as np

# %%
img = cv2.imread("/home/heemin/mv/code/img1.jpg")
img = np.expand_dims(img, axis=0)

# %%
model = DeepFace.build_model('VGG-Face')
print(img.shape) # (224, 224, 3)
print(model.input_shape) # (None, 224, 224, 3)
representation = model.predict(img)
# Out:
# vgg_face_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: /home/heemin/.deepface/weights/vgg_face_weights.h5
# 100%|██████████| 580M/580M [02:18<00:00, 4.18MB/s]
# (1, 1868, 1382, 3)
# (None, 224, 224, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-7072d920a985> in <module>
#       2 print(img.shape) # (224, 224, 3)
#       3 print(model.input_shape) # (None, 224, 224, 3)
# ----> 4 representation = model.predict(img)
#
# ~/.pyenv/versions/3.6.8/envs/meta/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1749           for step in data_handler.steps():
#    1750             callbacks.on_predict_batch_begin(step)
# ...

# %%
backends = [
  'opencv', 
  'ssd', 
  'dlib', 
  'mtcnn', 
  'retinaface', 
  'mediapipe'
]

#facial analysis
demographies = DeepFace.analyze(img_path = "img1.jpg", 
        detector_backend = backends[3]
)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-74fe62281408> in <module>
#      10 #facial analysis
#      11 demographies = DeepFace.analyze(img_path = "img1.jpg",
# ---> 12         detector_backend = backends[3]
#      13 )
#
# ~/.pyenv/versions/3.6.8/envs/meta/lib/python3.6/site-packages/deepface/DeepFace.py in analyze(img_path, actions, enforce_detection, detector_backend, align, silent)
#     275                                         img_gray = np.expand_dims(img_gray, axis = 0)
#     276
# --> 277                                         emotion_predictions = models['emotion'].predict(img_gray, verbose=0)[0,:]
#     278
#     279                                         sum_of_predictions = emotion_predictions.sum()
#
# ...

# %%
objs = DeepFace.analyze(img, actions = ['age', 'gender', 'race', 'emotion'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-ae2c51805e2a> in <module>
# ----> 1 objs = DeepFace.analyze(img, actions = ['age', 'gender', 'race', 'emotion'])
#
# ~/.pyenv/versions/3.6.8/envs/meta/lib/python3.6/site-packages/deepface/DeepFace.py in analyze(img_path, actions, enforce_detection, detector_backend, align, silent)
#     259         resp_objects = []
#     260
# --> 261         img_objs = functions.extract_faces(img=img_path, target_size=(224, 224), detector_backend=detector_backend, grayscale = False, enforce_detection=enforce_detection, align=align)
#     262
#     263         for img_content, img_region, img_confidence in img_objs:
#
# ~/.pyenv/versions/3.6.8/envs/meta/lib/python3.6/site-packages/deepface/commons/functions.py in extract_faces(img, target_size, detector_backend, grayscale, enforce_detection, align)
# ...
